# %%
# %load_ext autoreload
from envs import cartpole

import dartpy as dart
# %autoreload 2

# %%
a = cartpole.DartCartpoleEnv()
# Out:
# [ 0.00158836 -0.00500205  0.07941794 -0.25010267]

# %%
node = dart.gui.osg.RealTimeWorldNode(a.world)
viewer = dart.gui.osg.Viewer()
viewer.addWorldNode(node)

# %%
viewer.captureScreen('hi.png')

# %%
dir(dart.gui.osg.Viewer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'addAttachment',
#  'addEventHandler',
#  'addInstructionText',
#  'addWorldNode',
#  'allowSimulation',
#  'captureScreen',
#  'checkHeadlights',
#  'disableDragAndDrop',
#  'enableDragAndDrop',
#  'getInstructions',
#  'getVerticalFieldOfView',
#  'isAllowingSimulation',
#  'isRecording',
#  'isSimulating',
#  'pauseRecording',
#  'record',
#  'removeAttachment',
#  'removeWorldNode',
#  'run',
#  'setCameraHomePosition',
#  'setUpViewInWindow',
#  'setUpwardsDirection',
#  'setVerticalFieldOfView',
#  'setWorldNodeActive',
#  'setupDefaultLights',
#  'simulate',
#  'switchDefaultEventHandler',
# ...

# %%
dir(a.model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'checkIndexingConsistency',
#  'clearConstraintImpulses',
#  'clearExternalForces',
#  'clearIK',
#  'clearInternalForces',
#  'clone',
#  'cloneMetaSkeleton',
#  'computeForwardDynamics',
#  'computeForwardKinematics',
#  'computeImpulseForwardDynamics',
#  'computeInverseDynamics',
#  'computeKineticEnergy',
#  'computeLagrangian',
#  'computePotentialEnergy',
#  'createBallJointAndBodyNodePair',
#  'createEulerJointAndBodyNodePair',
#  'createFreeJointAndBodyNodePair',
#  'createPlanarJointAndBodyNodePair',
#  'createPrismaticJointAndBodyNodePair',
#  'createRevoluteJointAndBodyNodePair',
# ...

# %%
dir()
# Out:
# ['World',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'addConstraintImpulse',
#  'addExtForce',
#  'addExtTorque',
#  'clearConstraintImpulse',
#  'clearExternalForces',
#  'clearIK',
#  'clearInternalForces',
#  'computeKineticEnergy',
#  'computeLagrangian',
#  'computePotentialEnergy',
#  'copy',
#  'copyAs',
#  'copyTo',
#  'createBallJointAndBodyNodePair',
#  'createEulerJointAndBodyNodePair',
#  'createFreeJointAndBodyNodePair',
#  'createPlanarJointAndBodyNodePair',
#  'createPrismaticJointAndBodyNodePair',
#  'createRevoluteJointAndBodyNodePair',
#  'createScrewJointAndBodyNodePair',
#  'createShapeNode',
# ...
